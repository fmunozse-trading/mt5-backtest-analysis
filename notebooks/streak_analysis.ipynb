# %% [markdown]
# # MT5 Report Analysis
#
# This notebook parses the MT5 strategy tester report (HTML) and performs a streak analysis.

# %%
import pandas as pd
from bs4 import BeautifulSoup
import json
import matplotlib.pyplot as plt
import os

# %matplotlib inline

# %% [markdown]
# ## 1. Parse HTML Report
#
# We extract the 'Deals' table which contains the profit information.

# %%
# File path
#file_path = "../data/RT NDX 74.3k Pf 1.44 Rf 12.2 Dd 5.1 Csc 11.5.html"
#file_path = "C:/Users/Usuario/SynologyDrive/trading/exports/RB_R_ORO_EASYTRADING_V.0.1/RF9.92_PF1.52_DD8.81_Win42.60_RT_ReportTester-3000086403.html"
#file_path = "C:/Users/Usuario/SynologyDrive/trading/exports/RB_R_ORO_EASYTRADING_V.0.1/RF14.13_PF1.65_DD6.95_Win44.74_RT_ReportTester-3000086403.html"
file_path = "../data/NDX1.html"

json_output_path = "../data/parsed_trades.json"

# Read Content
try:
    with open(file_path, "r", encoding="utf-16") as f:
        content = f.read()
except UnicodeError:
    with open(file_path, "r", encoding="utf-8") as f:
        content = f.read()

soup = BeautifulSoup(content, "lxml") # using lxml for speed if available, else html.parser

# Find Tables
tables = soup.find_all("table")
print(f"Found {len(tables)} tables")

# Locate Deals Table
deals_data = []
if len(tables) > 1:
    # Usually the second table or the one with 'Profit' header
    main_table = tables[1]
    rows = main_table.find_all("tr")
    
    header_index = -1
    headers = []
    
    # Search for header
    for i, row in enumerate(rows):
        cells = [c.get_text(strip=True) for c in row.find_all(["th", "td"])]
        
        if ("Profit" in cells and "Time" in cells) or ("Beneficio" in cells and "Fecha/Hora" in cells):
            print(cells)

            header_index = i
            headers = cells
            print(f"Header found at row {i}: {headers}")
            break
            
    # Extract Data
    if header_index != -1:
        for row in rows[header_index+1:]:
            cells = [c.get_text(strip=True) for c in row.find_all("td")]
            if len(cells) != len(headers):
                continue
            
            record = dict(zip(headers, cells))
            deals_data.append(record)
            
print(f"Extracted {len(deals_data)} deals")

# Normalize Profit
# MT5 numbers might have spaces or weird formats
def clean_number(s):
    if not s: return 0.0
    s = s.replace(" ", "").replace(",", ".") # Handle potential european format if strictly needed, but MT5 reports usually use dots or spaces
    # Sometimes negatives are weird, but usually standard -100.00
    try:
        return float(s)
    except:
        return 0.0

if deals_data and 'Beneficio' in deals_data[0]:
    rename_map = {
        'Beneficio': 'Profit',
        'Dirección': 'Direction',
        'Fecha/Hora': 'Time',
        'Símbolo': 'Symbol',
        'Tipo': 'Type',
        'Volumen': 'Volume',
        'Precio': 'Price',
        'Comisión': 'Commission',
        'Swap': 'Swap',
        'Comentario': 'Comment',
        'ID de la orden': 'Order',
        'ID de la posición': 'Position'
    }
    deals_data = [{rename_map.get(k, k): v for k, v in d.items()} for d in deals_data]

for d in deals_data:
    d['Profit_Clean'] = clean_number(d.get('Profit', '0'))

# Save to JSON
with open(json_output_path, "w", encoding="utf-8") as f:
    json.dump(deals_data, f, indent=2, ensure_ascii=False)
    
print(f"Saved to {json_output_path}")
# Out:
# Found 2 tables
# ['Fecha/Hora', 'Transacción', 'Símbolo', 'Tipo', 'Dirección', 'Volumen', 'Precio', 'Orden', 'Comisión', 'Swap', 'Beneficio', 'Balance', 'Comentario']
# Header found at row 2475: ['Fecha/Hora', 'Transacción', 'Símbolo', 'Tipo', 'Dirección', 'Volumen', 'Precio', 'Orden', 'Comisión', 'Swap', 'Beneficio', 'Balance', 'Comentario']
# Extracted 2471 deals
# Saved to ../data/parsed_trades.json

# %% [markdown]
# ## 2. Streak Analysis
#
# We calculate a running 'Signed Streak' metric.
# - **Positive values (+1, +2, ...)** represent consecutive wins.
# - **Negative values (-1, -2, ...)** represent consecutive losses.
# - **Zero** is not used in this specific signed context, we transition directly between +1 and -1.

# %%
df = pd.DataFrame(deals_data)



# Filter for 'out' deals (realized profit)
trades = df[df['Direction'] == 'out'].copy()

# Convert Time to datetime
trades['Time'] = pd.to_datetime(trades['Time'])
trades.sort_values('Time', inplace=True)
trades.reset_index(drop=True, inplace=True)

print(f"Trades with P/L: {len(trades)}")

# Determine Win/Loss
trades['Result'] = trades['Profit_Clean'].apply(lambda x: 'Win' if x >= 0 else 'Loss')

# Calculate Signed Streak Counter
streak_counters = []
current_streak = 0

for res in trades['Result']:
    if res == 'Win':
        if current_streak >= 0:
            current_streak += 1
        else:
            current_streak = 1
    else: # Loss
        if current_streak <= 0:
            current_streak -= 1
        else:
            current_streak = -1
    streak_counters.append(current_streak)
    
trades['Signed_Streak'] = streak_counters
trades['Streak_Abs'] = trades['Signed_Streak'].abs()

# View sample
print(trades[['Time', 'Profit_Clean', 'Result', 'Signed_Streak']].head(10))
print(trades[['Time', 'Profit_Clean', 'Result', 'Signed_Streak']].tail(10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\dev\Source\python\test-examine-mt5-backtesting\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 10
# ...

# %% [markdown]
# ## 3. Visualization
#
# ### 3.1 Signed Streak vs Time
# This plot shows the momentum of wins (green, positive) and losses (red, negative) over time.

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

plt.figure(figsize=(14, 7))

# Define colors based on sign
colors = ['g' if x > 0 else 'r' for x in trades['Signed_Streak']]

# Bar plot of Signed Streak vs Trade Index (Sequence)
plt.bar(trades.index, trades['Signed_Streak'], color=colors, width=1.0, alpha=0.8)

plt.title('Trading Streaks Over Time (Sequential)', fontsize=16)
plt.xlabel('Trade Sequence Number', fontsize=12)
plt.ylabel('Consecutive Wins (+) / Losses (-)', fontsize=12)
plt.axhline(0, color='black', linewidth=0.5)
plt.grid(axis='y', alpha=0.3)

# Annotate max/min streaks
max_streak = trades['Signed_Streak'].max()
min_streak = trades['Signed_Streak'].min()

if not pd.isna(max_streak):
    idx_max = trades['Signed_Streak'].idxmax()
    plt.annotate(f'Max Win Streak: {max_streak}', 
                 xy=(idx_max, max_streak), 
                 xytext=(idx_max, max_streak + 2),
                 arrowprops=dict(facecolor='green', shrink=0.05),
                 ha='center')

if not pd.isna(min_streak):
    idx_min = trades['Signed_Streak'].idxmin()
    plt.annotate(f'Max Loss Streak: {min_streak}', 
                 xy=(idx_min, min_streak), 
                 xytext=(idx_min, min_streak - 2),
                 arrowprops=dict(facecolor='red', shrink=0.05),
                 ha='center')

plt.show()

# %% [markdown]
# ### 3.2 Streak Distributions (Pyramid)

# %%
# Calculate strict streak blocks for stats
block_streaks = []
current_type = None
current_count = 0
start_idx = 0
accumulated_profit = 0

for i, row in trades.iterrows():
    res = row['Result']
    profit = row['Profit_Clean']
    
    if res == current_type:
        current_count += 1
        accumulated_profit += profit
    else:
        if current_type is not None:
            block_streaks.append({
                'Type': current_type,
                'Count': current_count,
                'Start_Time': trades.loc[start_idx, 'Time'],
                'End_Time': trades.loc[i-1, 'Time'],
                'Total_Profit': accumulated_profit
            })
        current_type = res
        current_count = 1
        accumulated_profit = profit
        start_idx = i

# Add last one
if current_type is not None:
    block_streaks.append({
        'Type': current_type,
        'Count': current_count,
        'Start_Time': trades.loc[start_idx, 'Time'],
        'End_Time': trades.iloc[-1]['Time'],
        'Total_Profit': accumulated_profit
    })

streak_df = pd.DataFrame(block_streaks)

# Visualizing Distribution
plt.figure(figsize=(10, 6))
win_counts = streak_df[streak_df['Type'] == 'Win']['Count'].value_counts().sort_index()
loss_counts = streak_df[streak_df['Type'] == 'Loss']['Count'].value_counts().sort_index()

all_lengths = sorted(list(set(win_counts.index).union(set(loss_counts.index))))
win_freq = [win_counts.get(l, 0) for l in all_lengths]
loss_freq = [-loss_counts.get(l, 0) for l in all_lengths]

plt.barh(all_lengths, win_freq, color='green', label='Winners')
plt.barh(all_lengths, loss_freq, color='red', label='Losers')

plt.title('Win/Loss Streak Distribution')
plt.xlabel('Frequency')
plt.ylabel('Streak Length')
plt.yticks(all_lengths)
plt.axvline(0, color='k')
plt.legend()
plt.grid(axis='x', alpha=0.3)
plt.show()

# %% [markdown]
# ### 3.3 Streak Distribution Normal Fit
#
# Analysis of the Signed Streak distribution compared to a Normal Distribution.

# %%
import numpy as np
from scipy.stats import norm

# Data for distribution: Use Completed Streak Lengths (from streak_df)
# This ensures we count each 'streak' as one event, matching the pyramid chart logic.
# Windows are positive, Losses are negative.
streak_df['Signed_Count'] = streak_df.apply(lambda x: x['Count'] if x['Type'] == 'Win' else -x['Count'], axis=1)
data = streak_df['Signed_Count']

# Calculate Stats
mu, std = norm.fit(data)
median = np.median(data)

plt.figure(figsize=(12, 7))

# Plot Histogram (Density=False for raw counts)
# We use density=False (default) to show Frequency
n, bins, patches = plt.hist(data, bins=range(int(data.min()), int(data.max()) + 2), 
                            density=False, alpha=0.6, color='#66b3ff', label='Actual Data (Count)', align='left')

# Plot Normal Distribution Curve (Scaled to Frequency)
# Scaling factor = Total samples * Bin Width. Bin width is 1.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
scale_factor = len(data) # Total number of streaks
plt.plot(x, p * scale_factor, 'r--', linewidth=2, label=fr'Normal Dist ($\mu$={mu:.2f}, $\sigma$={std:.2f})')

# Add Vertical Lines for Mean and Median
plt.axvline(mu, color='k', linestyle='--', linewidth=1.5, label=f'Mean: {mu:.2f}')
plt.axvline(median, color='green', linestyle='-.', linewidth=1.5, label=f'Median: {median:.2f}')

plt.title('Signed Streak Distribution (Completed Streaks) & Normal Fit', fontsize=14)
plt.xlabel('Streak Length (Negative=Loss, Positive=Win)')
plt.ylabel('Frequency (Count)')
plt.legend()
plt.grid(True, alpha=0.3)

plt.show()

print(f"Mean: {mu:.4f}")
print(f"Median: {median:.4f}")
print(f"Standard Deviation: {std:.4f}")
# Out:
# Mean: -0.2090
# Median: 1.0000
# Standard Deviation: 2.4515

# %% [markdown]
# ## 4. Advanced Streak Analysis
#
# Detailed list of the most extreme streaks found.

# %%
# Top Winning Streaks
top_wins = streak_df[streak_df['Type'] == 'Win'].sort_values('Count', ascending=False).head(10)
print("--- Top 10 Winning Streaks ---")
display(top_wins[['Count', 'Start_Time', 'End_Time', 'Total_Profit']])

# Top Losing Streaks
top_losses = streak_df[streak_df['Type'] == 'Loss'].sort_values('Count', ascending=False).head(10)
print("\n--- Top 10 Losing Streaks ---")
display(top_losses[['Count', 'Start_Time', 'End_Time', 'Total_Profit']])
# Out:
# --- Top 10 Winning Streaks ---
#      Count          Start_Time            End_Time  Total_Profit
# 226      7 2024-04-05 22:00:00 2024-05-10 22:00:00       1026.13
# 74       6 2020-07-21 15:01:19 2020-07-23 19:03:42        947.20
# 22       5 2019-06-14 10:02:38 2019-06-25 06:11:51       1346.64
# 4        5 2019-02-15 22:00:00 2019-03-13 13:08:47        784.72
# 52       5 2020-02-21 10:09:39 2020-03-06 08:33:16        524.72
# 318      5 2025-09-22 15:20:12 2025-09-30 09:53:35        617.30
# 288      5 2025-03-31 12:39:18 2025-04-11 22:00:00        465.22
# 48       5 2020-02-14 22:00:00 2020-02-19 14:46:58        610.46
# 278      4 2025-01-31 18:24:03 2025-02-05 15:33:08        323.74
# 202      4 2023-10-12 15:36:07 2023-10-13 22:00:00        784.23
# --- Top 10 Losing Streaks ---
#      Count          Start_Time            End_Time  Total_Profit
# 83      10 2020-09-15 10:42:42 2020-11-04 02:32:21       -621.04
# ...
